# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
data_raw = pd.read_csv('data/Joshua_Tree_Airbnb_Raw.csv')

# %%
data_raw.head()
# Out:
#                                          address  location/lat  location/lng  \
# 0        Yucca Valley, California, United States      34.24900    -116.45600
# 1         Joshua Tree, California, United States      34.11147    -116.30378
# 2         Joshua Tree, California, United States      34.08794    -116.29278
# 3  Desert Hot Springs, California, United States      33.93468    -116.47309
# 4        Yucca Valley, California, United States      34.11445    -116.43170
#
#                                                 name  numberOfGuests  \
# 0  Starship Landing - Two Epic Houses (bonus: Ali...              16
# 1  SkyHouse Joshua Tree: Private Villa with Pool/Spa               6
# 2                    Joshua Tree Villa De La Collina              10
# 3     Whole Compound Buyout - Desert Special Inquiry              10
# 4  7BR Stargazing Lux Retreat Pool/Spa & Yoga Studio              16
#
#    pricing/nights  pricing/rate/amount pricing/rate/amountFormatted  \
# ...

# %%
# get all column names
with pd.option_context('display.max_seq_items', None):
    print (data_raw.columns)
# Out:
# Index(['address', 'location/lat', 'location/lng', 'name', 'numberOfGuests',
#        'pricing/nights', 'pricing/rate/amount', 'pricing/rate/amountFormatted',
#        'pricing/rate/currency', 'pricing/rate/isMicrosAccuracy',
#        'pricing/rateType', 'pricing/totalPrice/accommodation',
#        'pricing/totalPrice/amount', 'pricing/totalPrice/amountFormatted',
#        'pricing/totalPrice/cleaningFee', 'pricing/totalPrice/currency',
#        'pricing/totalPrice/discount', 'pricing/totalPrice/guestFee',
#        'pricing/totalPrice/taxes', 'reviews/0/author/firstName',
#        'reviews/0/author/hasProfilePic', 'reviews/0/author/id',
#        'reviews/0/author/pictureUrl', 'reviews/0/author/smartName',
#        'reviews/0/author/thumbnailUrl', 'reviews/0/collectionTag',
#        'reviews/0/comments', 'reviews/0/createdAt', 'reviews/0/id',
#        'reviews/0/localizedDate', 'reviews/0/localizedReview',
#        'reviews/0/rating', 'reviews/0/recipient/firstName',
# ...

# %%
columns_to_keep = ['address', 'location/lat', 'location/lng', 'name', 'numberOfGuests',
                   'pricing/nights', 'pricing/rate/amount', 'pricing/totalPrice/amount',
                   'pricing/totalPrice/cleaningFee', 'pricing/totalPrice/discount',
                   'pricing/totalPrice/guestFee', 'pricing/totalPrice/taxes']
